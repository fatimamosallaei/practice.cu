# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
os.getcwd()
# Out:
# 'C:\\Users\\Armin Nikzad'

# %%
os.chdir('C:\\Users\\Armin Nikzad\\Desktop\\Python_file\\Week5')

# %%
df=pd.read_csv('train_titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
#data rame contain 12 columns and 891 rows(based on passengerid), two columns with float type, five with int type and five with object type.
#memory usage is about 83 KB

# %%
df.drop(df.index[1])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# ...

# %%
df.drop('Embarked',axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 136          137         1       1
# 137          138         0       1
# 139          140         0       1
# ...

# %%
df.hist(column='Fare')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002335F703CC0>]],
#       dtype=object)

# %%
df.hist(column='Survived')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002335F9CBB38>]],
#       dtype=object)

# %%
plt.matshow(df.corr())
plt.show()

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_4552b250_fc37_11e9_a7c3_28d24458d9c8row0_col0 {
#             background-color:  #b40426;
#         }    #T_4552b250_fc37_11e9_a7c3_28d24458d9c8row0_col1 {
#             background-color:  #8caffe;
#         }    #T_4552b250_fc37_11e9_a7c3_28d24458d9c8row0_col2 {
#             background-color:  #a9c6fd;
#         }    #T_4552b250_fc37_11e9_a7c3_28d24458d9c8row0_col3 {
#             background-color:  #9dbdff;
#         }    #T_4552b250_fc37_11e9_a7c3_28d24458d9c8row0_col4 {
#             background-color:  #799cf8;
#         }    #T_4552b250_fc37_11e9_a7c3_28d24458d9c8row0_col5 {
#             background-color:  #6c8ff1;
#         }    #T_4552b250_fc37_11e9_a7c3_28d24458d9c8row0_col6 {
#             background-color:  #b3cdfb;
#         }    #T_4552b250_fc37_11e9_a7c3_28d24458d9c8row1_col0 {
#             background-color:  #4961d2;
#         }    #T_4552b250_fc37_11e9_a7c3_28d24458d9c8row1_col1 {
#             background-color:  #b40426;
# ...

# %%
df.loc[:,'doublefare'] = df['Fare']*2
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  doublefare
# 0      0         A/5 21171   7.2500   NaN        S     14.5000
# 1      0          PC 17599  71.2833   C85        C    142.5666
# 2      0  STON/O2. 3101282   7.9250   NaN        S     15.8500
# ...

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
 plt.scatter(df.Age, df.Fare, color="pink")
plt.xlabel('Age')
plt.ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %%
print (df.groupby('Survived').mean().std(axis=1))
# Out:
# Survived
# 0    163.516609
# 1    160.677120
# dtype: float64

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_0389f124_fc3d_11e9_a716_28d24458d9c8row0_col0 {
#             background-color:  #b40426;
#         }    #T_0389f124_fc3d_11e9_a716_28d24458d9c8row0_col1 {
#             background-color:  #8caffe;
#         }    #T_0389f124_fc3d_11e9_a716_28d24458d9c8row0_col2 {
#             background-color:  #a9c6fd;
#         }    #T_0389f124_fc3d_11e9_a716_28d24458d9c8row0_col3 {
#             background-color:  #96b7ff;
#         }    #T_0389f124_fc3d_11e9_a716_28d24458d9c8row0_col4 {
#             background-color:  #6788ee;
#         }    #T_0389f124_fc3d_11e9_a716_28d24458d9c8row0_col5 {
#             background-color:  #6a8bef;
#         }    #T_0389f124_fc3d_11e9_a716_28d24458d9c8row0_col6 {
#             background-color:  #b3cdfb;
#         }    #T_0389f124_fc3d_11e9_a716_28d24458d9c8row0_col7 {
#             background-color:  #b3cdfb;
#         }    #T_0389f124_fc3d_11e9_a716_28d24458d9c8row1_col0 {
#             background-color:  #4961d2;
# ...

# %%
#the top 3 correlated attributes to "Survived" whould be "Fare","pclass" and "parch"
